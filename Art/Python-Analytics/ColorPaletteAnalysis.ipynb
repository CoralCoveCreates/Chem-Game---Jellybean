# %% [markdown]
# ## Color Palette Analysis

# %%
import numpy as np
import PIL
from PIL import Image
import matplotlib.pyplot as plt

# %%
def countColors (img,colorCountsm):
    
    for x in range(img.width):
        for y in range(img.height):
            (r,g,b,a) = img.getpixel((x,y))
            colorCountsm[r,g,b] += 1 
            #if (r==131) and (g==128) and (b==137):
            #    print("I was here")
    return colorCountsm

# %%
import os
directory_in_str = "../Color Palette Dataset"
directory = os.fsencode(directory_in_str)

colorCountsm = np.zeros((256,256,256))
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".png"): 
        #print(filename)
        img = Image.open(directory_in_str + "/" + filename)
        if img.mode == 'RGBA' or 'rgba':
            colorCountsm = countColors(img,colorCountsm)
        else:
            print(filename)
    else:
        continue

# %%
colorCountsm[0:5,0:5,0]
# Out:
# array([[1.027076e+06, 2.210300e+04, 1.335800e+04, 7.598000e+03,
#         8.342000e+03],
#        [1.628100e+04, 1.012400e+04, 4.089000e+03, 5.225000e+03,
#         1.164000e+03],
#        [4.441000e+03, 7.963000e+03, 7.005000e+03, 2.515000e+03,
#         3.445000e+03],
#        [6.752000e+03, 1.495000e+03, 5.308000e+03, 1.095000e+03,
#         2.839000e+03],
#        [7.867000e+03, 1.591000e+03, 8.400000e+02, 2.141000e+03,
#         7.520000e+02]])

# %%
print(colorCountsm.mean())
print(colorCountsm.max())
print(colorCountsm.min())
print(colorCountsm.std())
print(colorCountsm.var())
# Out:
# 4.798474013805389
# 1027076.0
# 0.0
# 263.16346744466927
# 69255.01059750149

# %%
plt.imshow(colorCountsm[:,:,0], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,10], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,20], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,30], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,40], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,50], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,60], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,70], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,80], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,90], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,100], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,110], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,120], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,130], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,140], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,150], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,160], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,170], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,180], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,190], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,200], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,210], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,220], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,230], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,240], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsm[:,:,250], cmap='hot', interpolation='nearest')
plt.show()

# %%
import copy

# %%
highpass_colorCountsm = copy.deepcopy(colorCountsm)

# %%
highpass_colorCountsm[colorCountsm < 900] = 0

# %%
highpass_colorCountsm[0:5,0:5,0]
# Out:
# array([[1027076.,   22103.,   13358.,    7598.,    8342.],
#        [  16281.,   10124.,    4089.,    5225.,    1164.],
#        [   4441.,    7963.,    7005.,    2515.,    3445.],
#        [   6752.,    1495.,    5308.,    1095.,    2839.],
#        [   7867.,    1591.,       0.,    2141.,       0.]])

# %%
# 3D Heatmap in Python using matplotlib 
  
# to make plot interactive  
# %matplotlib 
  
# importing required libraries 
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt 
from pylab import *
  
# creating a dummy dataset 
#x = np.random.randint(low=100, high=500, size=(1000,)) 
#y = np.random.randint(low=300, high=500, size=(1000,)) 
#z = np.random.randint(low=200, high=500, size=(1000,)) 
colo = highpass_colorCountsm.flatten()
  
# creating figures 
fig = plt.figure(figsize=(10, 10)) 
ax = fig.add_subplot(111, projection='3d') 
  
# setting color bar 
color_map = cm.ScalarMappable(cmap=cm.Greens_r) 
color_map.set_array(colo) 
  
# creating the heatmap 
img = ax.scatter(x, y, z, marker='s', 
                 s=200, color='green') 
plt.colorbar(color_map) 
  
# adding title and labels 
ax.set_title("3D Heatmap") 
ax.set_xlabel('X-axis') 
ax.set_ylabel('Y-axis') 
ax.set_zlabel('Z-axis') 
  
# displaying plot 
plt.show()
