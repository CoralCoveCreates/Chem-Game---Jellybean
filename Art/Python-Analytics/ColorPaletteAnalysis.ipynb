# %% [markdown]
# ## Color Palette Analysis

# %%
import numpy as np
import PIL
from PIL import Image
import matplotlib.pyplot as plt

# %%
def countColors (img,colorCountsm):
    
    for x in range(img.width):
        for y in range(img.height):
            (r,g,b,a) = img.getpixel((x,y))
            colorCountsm[r,g,b] += 1 
            #if (r==131) and (g==128) and (b==137):
            #    print("I was here")
    return colorCountsm

# %%
import os
directory_in_str = "../Color Palette Dataset"
directory = os.fsencode(directory_in_str)

colorCountsm = np.zeros((256,256,256))
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".png"): 
        #print(filename)
        img = Image.open(directory_in_str + "/" + filename)
        if img.mode == 'RGBA' or 'rgba':
            colorCountsm = countColors(img,colorCountsm)
        else:
            print(filename)
    else:
        continue

# %%
colorCountsm[0:5,0:5,0]
# Out:
# array([[1.027076e+06, 2.210300e+04, 1.335800e+04, 7.598000e+03,
#         8.342000e+03],
#        [1.628100e+04, 1.012400e+04, 4.089000e+03, 5.225000e+03,
#         1.164000e+03],
#        [4.441000e+03, 7.963000e+03, 7.005000e+03, 2.515000e+03,
#         3.445000e+03],
#        [6.752000e+03, 1.495000e+03, 5.308000e+03, 1.095000e+03,
#         2.839000e+03],
#        [7.867000e+03, 1.591000e+03, 8.400000e+02, 2.141000e+03,
#         7.520000e+02]])

# %%
print(colorCountsm.mean())
print(colorCountsm.max())
print(colorCountsm.min())
print(colorCountsm.std())
print(colorCountsm.var())
# Out:
# 4.798474013805389
# 1027076.0
# 0.0
# 263.16346744466927
# 69255.01059750149

# %%
colorCountsFlippedm = np.flipud(colorCountsm)

# %% [markdown]
# plot axis labels incorrect

# %%
plt.imshow(colorCountsFlippedm[:,:,0], cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,10], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,20], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,30], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,40], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,50], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,60], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,70], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,80], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,90], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,100], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,110], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,120], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,130], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,140], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,150], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,160], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,170], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,180], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,190], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,200], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,210], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,220], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,230], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,240], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsFlippedm[:,:,250], cmap='hot', interpolation='nearest')
plt.show()

# %%
"""
# 3D Heatmap in Python using matplotlib 
  
# to make plot interactive  
# %matplotlib 
  
# importing required libraries 
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt 
from pylab import *
  
# creating a dummy dataset 
#x = np.random.randint(low=100, high=500, size=(1000,)) 
#y = np.random.randint(low=300, high=500, size=(1000,)) 
#z = np.random.randint(low=200, high=500, size=(1000,)) 
colo = highpass_colorCountsm.flatten()
  
# creating figures 
fig = plt.figure(figsize=(10, 10)) 
ax = fig.add_subplot(111, projection='3d') 
  
# setting color bar 
color_map = cm.ScalarMappable(cmap=cm.Greens_r) 
color_map.set_array(colo) 
  
# creating the heatmap 
img = ax.scatter(x, y, z, marker='s', 
                 s=200, color='green') 
plt.colorbar(color_map) 
  
# adding title and labels 
ax.set_title("3D Heatmap") 
ax.set_xlabel('X-axis') 
ax.set_ylabel('Y-axis') 
ax.set_zlabel('Z-axis') 
  
# displaying plot 
plt.show() 
"""
# Out:
# '\n# 3D Heatmap in Python using matplotlib \n  \n# to make plot interactive  \n%matplotlib \n  \n# importing required libraries \nfrom mpl_toolkits.mplot3d import Axes3D \nimport matplotlib.pyplot as plt \nfrom pylab import *\n  \n# creating a dummy dataset \n#x = np.random.randint(low=100, high=500, size=(1000,)) \n#y = np.random.randint(low=300, high=500, size=(1000,)) \n#z = np.random.randint(low=200, high=500, size=(1000,)) \ncolo = highpass_colorCountsm.flatten()\n  \n# creating figures \nfig = plt.figure(figsize=(10, 10)) \nax = fig.add_subplot(111, projection=\'3d\') \n  \n# setting color bar \ncolor_map = cm.ScalarMappable(cmap=cm.Greens_r) \ncolor_map.set_array(colo) \n  \n# creating the heatmap \nimg = ax.scatter(x, y, z, marker=\'s\', \n                 s=200, color=\'green\') \nplt.colorbar(color_map) \n  \n# adding title and labels \nax.set_title("3D Heatmap") \nax.set_xlabel(\'X-axis\') \nax.set_ylabel(\'Y-axis\') \nax.set_zlabel(\'Z-axis\') \n  \n# displaying plot \npl
# ...

# %%
import copy

# %%
highpass_colorCountsm = copy.deepcopy(colorCountsm)

# %%
highpass_colorCountsm[colorCountsm < 900] = 0

# %%
highpass_colorCountsm[0:5,0:5,0]
# Out:
# array([[1027076.,   22103.,   13358.,    7598.,    8342.],
#        [  16281.,   10124.,    4089.,    5225.,    1164.],
#        [   4441.,    7963.,    7005.,    2515.,    3445.],
#        [   6752.,    1495.,    5308.,    1095.,    2839.],
#        [   7867.,    1591.,       0.,    2141.,       0.]])

# %%
plt.imshow(highpass_colorCountsm[:,:,250], cmap='hot', interpolation='nearest')
plt.show()

# %%
colorCountsm < 5000
# Out:
# array([[[False, False, False, ...,  True,  True,  True],
#         [False,  True,  True, ...,  True,  True,  True],
#         [False, False,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[False,  True,  True, ...,  True,  True,  True],
#         [False, False,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#
#        [[ True, False,  True, ...,  True,  True,  True],
#         [False,  True,  True, ...,  True,  True,  True],
#         [False,  True, False, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
# ...

# %%
commonColorsl = []
for x in range(colorCountsm.shape[0]):
    for y in range(colorCountsm.shape[1]):
        for z in range(colorCountsm.shape[2]):
            if colorCountsm[x,y,z] > 5000:
                commonColorsl.append((x,y,z))

# %%
len(commonColorsl)
# Out:
# 163

# %%
refinedCommonColorsl = []
for color in commonColorsl:
    if color[0] > 5 and color[1] > 5 and color[2]>5:
        refinedCommonColorsl.append(color)

# %%
len(refinedCommonColorsl)
# Out:
# 85

# %%
import math

# %%
math.sqrt(85)
# Out:
# 9.219544457292887

# %%
blocksWidth = 10
blocksHeight = 9 

palette1m = np.zeros((10,9,3))
i_=0
for x in range(palette1m.shape[0]):
    for y in range(palette1m.shape[1]):
            if i_<85:
                palette1m[x,y] = np.array(refinedCommonColorsl[i_])
            i_+=1

# %%
palette1m[0:10,0,:]
# Out:
# array([[  6.,   6.,   6.],
#        [  9.,  14.,  20.],
#        [ 20.,  17.,  12.],
#        [129., 111.,  87.],
#        [192., 210., 243.],
#        [239., 240., 244.],
#        [244., 245., 239.],
#        [247., 247., 247.],
#        [250., 250., 248.],
#        [253., 252., 234.]])

# %%
palette1m[0,0,:]
# Out:
# array([6., 6., 6.])

# %%
paletteBitmapImagem = np.zeros((10*20,9*20,3))
paletteBitmapImagem.shape
# Out:
# (200, 180, 3)

# %%
i_=0
for x in range(blocksWidth):
    for y in range(blocksHeight):
            if i_<85:
                pbi_startx = x*20
                pbi_endx = (x*20)+20
                pbi_starty = y*20 
                pbi_endy = (y*20)+20
                paletteBitmapImagem[pbi_startx:pbi_endx, pbi_starty:pbi_endy, :] =  refinedCommonColorsl[i_]
            i_+=1

# %%
paletteBitmapImagem = paletteBitmapImagem.astype(int)

# %%
plt.imshow(paletteBitmapImagem)
plt.show()

# %% [markdown]
# The most common colors are probably background colors and they aren't great.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# colorCountsm
