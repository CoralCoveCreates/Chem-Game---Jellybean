# %% [markdown]
# ## Color Palette Analysis

# %%
import numpy as np
import math
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import copy

# %%
def countColors (img,colorCountsm):
    
    for x in range(img.width):
        for y in range(img.height):
            (r,g,b,a) = img.getpixel((x,y))
            colorCountsm[r,g,b] += 1 
            #if (r==131) and (g==128) and (b==137):
            #    print("I was here")
    return colorCountsm

# %%
import os
directory_in_str = "../Color Palette Dataset"
directory = os.fsencode(directory_in_str)

colorCountsm = np.zeros((256,256,256))
for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith(".png"): 
        #print(filename)
        img = Image.open(directory_in_str + "/" + filename)
        if img.mode == 'RGBA' or 'rgba':
            colorCountsm = countColors(img,colorCountsm)
        else:
            print(filename)
    else:
        continue

# %%
colorCountsm[0:5,0:5,0]
# Out:
# array([[3.692343e+06, 9.110500e+04, 3.847200e+04, 1.710500e+04,
#         1.719800e+04],
#        [5.934000e+04, 5.346400e+04, 1.071800e+04, 1.369700e+04,
#         2.874000e+03],
#        [1.120590e+05, 2.296800e+04, 2.439800e+04, 6.907000e+03,
#         6.235000e+03],
#        [1.856700e+04, 3.563000e+03, 1.979800e+04, 2.667000e+03,
#         6.993000e+03],
#        [2.020700e+04, 3.697000e+03, 1.856000e+03, 5.305000e+03,
#         1.718000e+03]])

# %%
print(colorCountsm.mean())
print(colorCountsm.max())
print(colorCountsm.min())
print(colorCountsm.std())
print(colorCountsm.var())
# Out:
# 11.522751808166504
# 3692343.0
# 0.0
# 950.9329500940506
# 904273.4755745741

# %% [markdown]
# Removing pure black outlier

# %%
colorCountsm[0,0,0] =0

# %%
colorCountsm = colorCountsm + 0.1
colorCountsLogm = np.log(copy.deepcopy(colorCountsm))

# %%
print(colorCountsLogm.mean())
print(colorCountsLogm.max())
print(colorCountsLogm.min())
print(colorCountsLogm.std())
print(colorCountsLogm.var())
# Out:
# 0.23589869197507263
# 13.813578793307816
# -2.3025850929940455
# 2.2275756580725363
# 4.962093312437293

# %%
#colorCountsV1m = colorCountsm[colorCountsm != 0]
#colorCountsLogm = np.log(colorCountsV1m)
#print(colorCountsLogm.mean())
#print(colorCountsLogm.max())
#print(colorCountsLogm.min())
#print(colorCountsLogm.std())
#print(colorCountsLogm.var())
#Removing outliers in top quartile
#colorCountsV1m[colorCountsV1m > 25000] = 0
#colorCountsV1m = colorCountsV1m[colorCountsV1m >100 ]
#colorCountsV1m = colorCountsV1m[colorCountsV1m < 2500 ]
#print(len(copy.deepcopy(colorCountsm).flatten()))
#print(len(copy.deepcopy(colorCountsV1m).flatten()))

# %%
colorCountsFlattened = copy.deepcopy(colorCountsLogm).flatten()
plt.boxplot(colorCountsFlattened)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cd94574ad0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cd945750d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cd8438e0c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cd94575700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cd94575a00>],
#  'means': []}

# %%
#create histogram with density curve overlaid
sns.displot(colorCountsFlattened, kde=True, bins=100)

# %% [markdown]
# Color is distributed exponentially

# %%
#colorCountsFlippedm = np.flipud(colorCountsLogm)

# %% [markdown]
# plot axis labels incorrect

# %%
plt.imshow(colorCountsLogm[:,:,0], cmap='hot', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,10], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,20], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,30], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,40], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,50], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,60], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,70], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,80], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,90], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,100], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,110], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,120], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,130], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,140], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,150], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,160], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,170], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,180], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,190], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,200], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,210], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,220], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,230], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,240], cmap='hot', interpolation='nearest')
plt.show()

# %%
plt.imshow(colorCountsLogm[:,:,250], cmap='hot', interpolation='nearest')
plt.show()

# %%
"""
# 3D Heatmap in Python using matplotlib 
  
# to make plot interactive  
# %matplotlib 
  
# importing required libraries 
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt 
from pylab import *
  
# creating a dummy dataset 
#x = np.random.randint(low=100, high=500, size=(1000,)) 
#y = np.random.randint(low=300, high=500, size=(1000,)) 
#z = np.random.randint(low=200, high=500, size=(1000,)) 
colo = highpass_colorCountsm.flatten()
  
# creating figures 
fig = plt.figure(figsize=(10, 10)) 
ax = fig.add_subplot(111, projection='3d') 
  
# setting color bar 
color_map = cm.ScalarMappable(cmap=cm.Greens_r) 
color_map.set_array(colo) 
  
# creating the heatmap 
img = ax.scatter(x, y, z, marker='s', 
                 s=200, color='green') 
plt.colorbar(color_map) 
  
# adding title and labels 
ax.set_title("3D Heatmap") 
ax.set_xlabel('X-axis') 
ax.set_ylabel('Y-axis') 
ax.set_zlabel('Z-axis') 
  
# displaying plot 
plt.show() 
"""
# Out:
# '\n# 3D Heatmap in Python using matplotlib \n  \n# to make plot interactive  \n%matplotlib \n  \n# importing required libraries \nfrom mpl_toolkits.mplot3d import Axes3D \nimport matplotlib.pyplot as plt \nfrom pylab import *\n  \n# creating a dummy dataset \n#x = np.random.randint(low=100, high=500, size=(1000,)) \n#y = np.random.randint(low=300, high=500, size=(1000,)) \n#z = np.random.randint(low=200, high=500, size=(1000,)) \ncolo = highpass_colorCountsm.flatten()\n  \n# creating figures \nfig = plt.figure(figsize=(10, 10)) \nax = fig.add_subplot(111, projection=\'3d\') \n  \n# setting color bar \ncolor_map = cm.ScalarMappable(cmap=cm.Greens_r) \ncolor_map.set_array(colo) \n  \n# creating the heatmap \nimg = ax.scatter(x, y, z, marker=\'s\', \n                 s=200, color=\'green\') \nplt.colorbar(color_map) \n  \n# adding title and labels \nax.set_title("3D Heatmap") \nax.set_xlabel(\'X-axis\') \nax.set_ylabel(\'Y-axis\') \nax.set_zlabel(\'Z-axis\') \n  \n# displaying plot \npl
# ...

# %%
highpass_colorCountsm = copy.deepcopy(colorCountsm)

# %%
highpass_colorCountsm[colorCountsm < 900] = 0

# %%
highpass_colorCountsm[0:5,0:5,0]
# Out:
# array([[     0. ,  91105.1,  38472.1,  17105.1,  17198.1],
#        [ 59340.1,  53464.1,  10718.1,  13697.1,   2874.1],
#        [112059.1,  22968.1,  24398.1,   6907.1,   6235.1],
#        [ 18567.1,   3563.1,  19798.1,   2667.1,   6993.1],
#        [ 20207.1,   3697.1,   1856.1,   5305.1,   1718.1]])

# %%
plt.imshow(highpass_colorCountsm[:,:,250], cmap='hot', interpolation='nearest')
plt.show()

# %%
"""
palette1m = np.zeros((10,9,3))
i_=0
for x in range(palette1m.shape[0]):
    for y in range(palette1m.shape[1]):
            if i_<85:
                palette1m[x,y] = np.array(refinedCommonColorsl[i_])
            i_+=1

palette1m[0:10,0,:]
palette1m[0,0,:]
"""
# Out:
# '\npalette1m = np.zeros((10,9,3))\ni_=0\nfor x in range(palette1m.shape[0]):\n    for y in range(palette1m.shape[1]):\n            if i_<85:\n                palette1m[x,y] = np.array(refinedCommonColorsl[i_])\n            i_+=1\n\npalette1m[0:10,0,:]\npalette1m[0,0,:]\n'

# %%
def makeColorl (colorCountsm_, lowerbound_, upperbound_= colorCountsm.max()+1):
    commonColorsl = []
    for x in range(colorCountsm_.shape[0]):
        for y in range(colorCountsm_.shape[1]):
            for z in range(colorCountsm_.shape[2]):
                if colorCountsm_[x,y,z] > lowerbound_ and colorCountsm_[x,y,z] < upperbound_:
                    commonColorsl.append((x,y,z))

    print("Number of colors in common colors list", len(commonColorsl))

    refinedCommonColorsl = []
    for color in commonColorsl:
        if color[0] > 5 and color[1] > 5 and color[2]>5:
            refinedCommonColorsl.append(color)

    print("Number of colors in refined common colors list", len(refinedCommonColorsl))
    print("Roughly how many blocks wide and blocks tall does the palette need to be? ", np.round(math.sqrt(len(refinedCommonColorsl)),2))
    return refinedCommonColorsl


def makePaletteBitmapImagem (nBlocksWide: int, nBlocksHigh: int, colorl:list, blockSize=20):

    paletteBitmapImagem = np.zeros((nBlocksWide*blockSize,nBlocksHigh*blockSize,3))
    nBlocksInImage = nBlocksWide*nBlocksHigh
    nColors = len(colorl)

    if nBlocksInImage < nColors:
         raise ValueError("Too many colors and not enough blocks for them in the image ")
    else:
        i_=0
        for x in range(nBlocksWide):
            for y in range(nBlocksHigh):
                    if i_<len(colorl):
                        pbi_startx = x*blockSize
                        pbi_endx = (x*blockSize)+blockSize
                        pbi_starty = y*blockSize 
                        pbi_endy = (y*blockSize)+blockSize
                        paletteBitmapImagem[pbi_startx:pbi_endx, pbi_starty:pbi_endy, :] =  colorl[i_]
                    i_+=1

        paletteBitmapImagem = paletteBitmapImagem.astype(int)
        return paletteBitmapImagem

# %%
colorl_gt5000 = makeColorl(colorCountsm_=colorCountsm, lowerbound_=5000)
# Out:
# Number of colors in common colors list 669
# Number of colors in refined common colors list 231
# Roughly how many blocks wide and blocks tall does the palette need to be?  15.2

# %%
try:
    paletteBitmapImagem_0 = makePaletteBitmapImagem(nBlocksWide=10, nBlocksHigh=9, colorl=colorl_gt5000)
    plt.imshow(paletteBitmapImagem_0)
    plt.show()
except ValueError as e:
    print(e)
# Out:
# Too many colors and not enough blocks for them in the image

# %% [markdown]
# The most common colors are probably background colors and they aren't great.

# %%
#n = 30
#max_minus_nstd = int(np.round(colorCountsm.max() - colorCountsm.std()*n,0))
#print(max_minus_nstd)
#print(colorCountsm.max())
colorl_gt5000_ls10000 = makeColorl(colorCountsm_=colorCountsm, lowerbound_=5000, upperbound_=10000)
# Out:
# Number of colors in common colors list 423
# Number of colors in refined common colors list 163
# Roughly how many blocks wide and blocks tall does the palette need to be?  12.77

# %%
try:
    paletteBitmapImagem_1 = makePaletteBitmapImagem(nBlocksWide=8, nBlocksHigh=8, colorl=colorl_gt5000_ls10000)
    plt.imshow(paletteBitmapImagem_1)
    plt.show()
except ValueError as e:
    print(e)
# Out:
# Too many colors and not enough blocks for them in the image

# %%
colorl_gt1000_ls1050 = makeColorl(colorCountsm_=colorCountsm, lowerbound_=1000, upperbound_=1050)
# Out:
# Number of colors in common colors list 586
# Number of colors in refined common colors list 352
# Roughly how many blocks wide and blocks tall does the palette need to be?  18.76

# %%
try:
    paletteBitmapImagem_1 = makePaletteBitmapImagem(nBlocksWide=13, nBlocksHigh=13, colorl=colorl_gt1000_ls1050)
    plt.imshow(paletteBitmapImagem_1)
    plt.show()
except ValueError as e:
    print(e)
# Out:
# Too many colors and not enough blocks for them in the image

# %%
colorl_gt2000_ls2200 = makeColorl(colorCountsm_=colorCountsm, lowerbound_=2000, upperbound_=2200)
# Out:
# Number of colors in common colors list 374
# Number of colors in refined common colors list 177
# Roughly how many blocks wide and blocks tall does the palette need to be?  13.3

# %%
try:
    paletteBitmapImagem_1 = makePaletteBitmapImagem(nBlocksWide=8, nBlocksHigh=6, colorl=colorl_gt2000_ls2200)
    plt.imshow(paletteBitmapImagem_1)
    plt.show()
except ValueError as e:
    print(e)
# Out:
# Too many colors and not enough blocks for them in the image

# %%
colorl_gt200_ls201 = makeColorl(colorCountsm_=colorCountsm, lowerbound_=200, upperbound_=201)
# Out:
# Number of colors in common colors list 723
# Number of colors in refined common colors list 582
# Roughly how many blocks wide and blocks tall does the palette need to be?  24.12

# %%
try:
    paletteBitmapImagem_1 = makePaletteBitmapImagem(nBlocksWide=18, nBlocksHigh=16, colorl=colorl_gt200_ls201)
    plt.imshow(paletteBitmapImagem_1)
    plt.show()
except ValueError as e:
    print(e)
# Out:
# Too many colors and not enough blocks for them in the image

# %% [markdown]
# ### Save Palette Pictures

# %%
plt.imshow(colorCountsLogm[:,:,250], cmap='hot', interpolation='nearest')
plt.show()

# %%
def make_palette_images (blue, color_m, threshold = 1):
    """ 
    Returns a pil image and also saves it as a .png to the Palette folder

    Keyword Arguments:
    blue -- an int between 0 and 255
    color_m  -- an np.array with shape (255,255,255) containing the count of each color 
                    that occured in the dataset
    threshold -- The counts of each color must be greater than this threshold in order
                     to be recorded in the palette. Currently defaults to 1 because it
                     expects logged data. 
    """
    b_ = blue
    palette_bitm_b_ = np.zeros((256,256,3), dtype=np.uint8)

    for r_ in range(256):
        for g_ in range(256):
            for color_ in range(3):
                if color_m[r_,g_,b_] > threshold:
                    match color_:
                        case 0:
                            palette_bitm_b_[r_, g_, color_] = int(r_)
                        case 1:
                            palette_bitm_b_[r_, g_, color_] = int(g_)
                        case 2:
                            palette_bitm_b_[r_, g_, color_] = int(b_)

    img = Image.fromarray(palette_bitm_b_, 'RGB')
    filename = './Palettes/'+ str(b_)+ '.png'
    img.save(filename)
    #img.show()
    return img

# %%
img = make_palette_images(blue = 250,color_m = colorCountsLogm)
img.show()

# %%
for blue in range(256):
    make_palette_images(blue,color_m = colorCountsLogm)

# %% [markdown]
# #### Save Heatmap Pictures
